# %% [markdown]
# <a href="https://colab.research.google.com/github/Meshal-Css/my-project-/blob/main/project_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# library basic

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("uom190346a/sleep-health-and-lifestyle-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/sleep-health-and-lifestyle-dataset

# %%
# data
data = pd.read_csv('/kaggle/input/sleep-health-and-lifestyle-dataset/Sleep_health_and_lifestyle_dataset.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.dtypes
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# dtype: object

# %%
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
data.shape
# Out:
# (374, 13)

# %%
data.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
# data processing
for i in data.columns.tolist():
  print (data [i].value_counts())
  print('---')
# Out:
# Person ID
# 374    1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 11     1
# 10     1
# 9      1
# 8      1
# 7      1
# Name: count, Length: 374, dtype: int64
# ---
# Gender
# Male      189
# Female    185
# Name: count, dtype: int64
# ---
# Age
# 43    34
# 44    30
# 37    20
# 38    20
# 50    20
# 31    18
# 32    17
# 53    17
# 59    16
# 39    15
# 45    14
# 33    13
# 29    13
# 30    13
# 36    12
# 35    12
# 41    12
# 49    11
# 42     9
# 57     9
# 52     9
# 51     8
# 54     7
# 58     6
# 28     5
# 40     4
# 48     3
# 55     2
# 34     2
# 56     2
# 27     1
# Name: count, dtype: int64
# ---
# Occupation
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Scientist                4
# Software Engineer        4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64
# ...

# %%
# explin columns
'''
Person ID: An identifier for each individual.
Gender: The gender of the person (Male/Female).
Age: The age of the person in years.
Occupation: The occupation or profession of the person.المهنة
Sleep Duration (hours): The number of hours the person sleeps per day.مدة عدد ساعات الشخص في اليوم
Quality of Sleep (scale: 1-10): A subjective rating of the quality of sleep, ranging from 1 to 10.
Physical Activity Level (minutes/day): The number of minutes the person engages in physical activity daily. النشاط البدني التيس يمارسة الشخص في اليوم
Stress Level (scale: 1-10): A subjective rating of the stress level experienced by the person, ranging from 1 to 10. مستوى التوتر لدى  الشخص في اليوم
BMI Category: The BMI category of the person (e.g., Underweight, Normal, Overweight).وزن الجسم
Blood Pressure (systolic/diastolic): The blood pressure measurement of the person, indicated as systolic pressure over diastolic pressure.ضغط الدم انقباضي وانبساطي
Heart Rate (bpm): The resting heart rate of the person in beats per minute.نبضات القلب بالدقيقة
Daily Steps: The number of steps the person takes per day.عدد خطوات الشخص في اليوم
Sleep Disorder: The presence or absence of a sleep disorder in the person (None, Insomnia, Sleep Apnea).اضطراب النوم





'''
# Out:
# '\nPerson ID: An identifier for each individual.\nGender: The gender of the person (Male/Female).\nAge: The age of the person in years.\nOccupation: The occupation or profession of the person.المهنة\nSleep Duration (hours): The number of hours the person sleeps per day.مدة عدد ساعات الشخص في اليوم\nQuality of Sleep (scale: 1-10): A subjective rating of the quality of sleep, ranging from 1 to 10.\nPhysical Activity Level (minutes/day): The number of minutes the person engages in physical activity daily. النشاط البدني التيس يمارسة الشخص في اليوم\nStress Level (scale: 1-10): A subjective rating of the stress level experienced by the person, ranging from 1 to 10. مستوى التوتر لدى  الشخص في اليوم\nBMI Category: The BMI category of the person (e.g., Underweight, Normal, Overweight).وزن الجسم\nBlood Pressure (systolic/diastolic): The blood pressure measurement of the person, indicated as systolic pressure over diastolic pressure.ضغط الدم انقباضي وانبساطي\nHeart Rate (bpm): The resting heart
# ...

# %%
# cheack null values in columns
data.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %% [markdown]
# I have researched the important factors related to sleep quality, the most important of which are stress, work, and eating.

# %%
data['Sleep Disorder'].value_counts()
# Out:
# Sleep Disorder
# Sleep Apnea    78
# Insomnia       77
# Name: count, dtype: int64

# %%
# what is correct answer here ?
data['Sleep Disorder'] = data["Sleep Disorder"].replace(np.nan,"Normal")

# %%
data['Sleep Disorder'].value_counts()
# Out:
# Sleep Disorder
# Normal         219
# Sleep Apnea     78
# Insomnia        77
# Name: count, dtype: int64

# %%
data['Blood Pressure'].value_counts()
# Out:
# Blood Pressure
# 130/85    99
# 140/95    65
# 125/80    65
# 120/80    45
# 115/75    32
# 135/90    27
# 140/90     4
# 125/82     4
# 128/85     3
# 132/87     3
# 117/76     2
# 130/86     2
# 126/83     2
# 119/77     2
# 135/88     2
# 128/84     2
# 131/86     2
# 139/91     2
# 115/78     2
# 129/84     2
# 142/92     2
# 118/75     2
# 118/76     1
# 122/80     1
# 121/79     1
# Name: count, dtype: int64

# %%
# data columns [Blood Pressure] in info object !  no  object here value here number what correct answer here split column after drop new coulmns in data frame

# %%
data[['systolic','diastolic']] = data['Blood Pressure'].str.split('/', expand = True).astype(int)

# %%
data.drop('Blood Pressure', axis = 1, inplace = True)

# %%
data.sample(3)
# Out:
#      Person ID Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 146        147   Male   39     Lawyer             7.2                 8
# 213        214   Male   43   Engineer             7.8                 8
# 36          37   Male   31     Doctor             6.1                 6
#
#      Physical Activity Level  Stress Level BMI Category  Heart Rate  \
# 146                       60             5       Normal          68
# 213                       90             5       Normal          70
# 36                        30             8       Normal          72
#
#      Daily Steps Sleep Disorder  systolic  diastolic
# 146         8000       Insomnia       130         85
# 213         8000         Normal       130         85
# 36          5000         Normal       125         80

# %%
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#    Heart Rate  Daily Steps Sleep Disorder  systolic  diastolic
# 0          77         4200         Normal       126         83
# ...

# %%
gender_counts = data['Gender'].value_counts()
labels = gender_counts.index.tolist()
sizes = gender_counts.values.tolist()
colors = ['lightblue', 'lightcoral']

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90,
       wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True)

ax.axis('equal')
ax.set_title('Gender Distribution')

plt.show()

# %%
occupation_counts = data['Occupation'].value_counts()
labels = occupation_counts.index.tolist()
sizes = occupation_counts.values.tolist()
colors = ['lightblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightcyan']

fig, ax = plt.subplots()
wedges, texts, autotexts = ax.pie(sizes, colors=colors, autopct='%1.1f%%', startangle=90,
                                  wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True)

ax.axis('equal')
ax.set_title('Occupation Distribution')


ax.legend(wedges, labels, title="Occupation", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

plt.show()

# %% [markdown]
# drop columns bmi !!!

# %%
bmi_counts = data['BMI Category'].value_counts()
labels = bmi_counts.index.tolist()
sizes = bmi_counts.values.tolist()
colors = ['lightblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightcyan']

fig, ax = plt.subplots()
wedges, texts, autotexts = ax.pie(sizes, colors=colors, autopct='%1.1f%%', startangle=90,
                                  wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True)

ax.axis('equal')
ax.set_title('BMI Category Distribution')


ax.legend(wedges, labels, title="BMI Category", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

plt.show()

# %%
sleep_disorder_counts = data['Sleep Disorder'].value_counts()
labels = sleep_disorder_counts.index.tolist()
sizes = sleep_disorder_counts.values.tolist()


x = np.arange(len(labels))
y = np.zeros(len(labels))
z = sizes


fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.stem(x, y, z)


ax.set_xticks(x)
ax.set_xticklabels(labels)
# Out:
# [Text(0, 0, 'Normal'), Text(1, 0, 'Sleep Apnea'), Text(2, 0, 'Insomnia')]

# %%
data.head()
data.drop('Person ID', axis = 1, inplace = True)

# %%
data.head()
data.drop('BMI Category', axis = 1, inplace = True)

# %%
data.head()
# Out:
#   Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0   Male   27     Software Engineer             6.1                 6
# 1   Male   28                Doctor             6.2                 6
# 2   Male   28                Doctor             6.2                 6
# 3   Male   28  Sales Representative             5.9                 4
# 4   Male   28  Sales Representative             5.9                 4
#
#    Physical Activity Level  Stress Level  Heart Rate  Daily Steps  \
# 0                       42             6          77         4200
# 1                       60             8          75        10000
# 2                       60             8          75        10000
# 3                       30             8          85         3000
# 4                       30             8          85         3000
#
#   Sleep Disorder  systolic  diastolic
# 0         Normal       126         83
# 1         Normal       125         80
# ...

# %%
data.columns
# Out:
# Index(['Gender', 'Age', 'Occupation', 'Sleep Duration', 'Quality of Sleep',
#        'Physical Activity Level', 'Stress Level', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder', 'systolic', 'diastolic'],
#       dtype='object')

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Sleep Disorder', y='Age', data=data)
plt.title('Age Distribution by Sleep Disorder Type')
plt.xlabel('Sleep Disorder')
plt.ylabel('Age')
plt.grid(True)
plt.show()

# %%
data.head(10)
# Out:
#   Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0   Male   27     Software Engineer             6.1                 6
# 1   Male   28                Doctor             6.2                 6
# 2   Male   28                Doctor             6.2                 6
# 3   Male   28  Sales Representative             5.9                 4
# 4   Male   28  Sales Representative             5.9                 4
# 5   Male   28     Software Engineer             5.9                 4
# 6   Male   29               Teacher             6.3                 6
# 7   Male   29                Doctor             7.8                 7
# 8   Male   29                Doctor             7.8                 7
# 9   Male   29                Doctor             7.8                 7
#
#    Physical Activity Level  Stress Level  Heart Rate  Daily Steps  \
# 0                       42             6          77         4200
# ...

# %% [markdown]
# ok now 3 columns categoracl transforms to num .

# %%
# sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
encoder = LabelEncoder()

# %%
data['Gender'] = encoder.fit_transform(data["Gender"])

# %%
occupation_map = {
    'Nurse': 0,
    'Doctor': 1,
    'Engineer': 2,
    'Lawyer': 3,
    'Teacher': 4,
    'Accountant': 5,
    'Salesperson': 6,
    'Scientist': 7,
    'Software Engineer': 8,
    'Sales Representative': 9,
    'Manager': 10
}

data['Occupation_encoded'] = data['Occupation'].map(occupation_map)

# %%
data.drop('Occupation', axis = 1, inplace = True)

# %%
data
# Out:
#      Gender  Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0         1   27             6.1                 6                       42
# 1         1   28             6.2                 6                       60
# 2         1   28             6.2                 6                       60
# 3         1   28             5.9                 4                       30
# 4         1   28             5.9                 4                       30
# ..      ...  ...             ...               ...                      ...
# 369       0   59             8.1                 9                       75
# 370       0   59             8.0                 9                       75
# 371       0   59             8.1                 9                       75
# 372       0   59             8.1                 9                       75
# 373       0   59             8.1                 9                       75
#
# ...

# %%
data['Sleep Disorder'] = encoder.fit_transform(data["Sleep Disorder"])

# %%
data
# Out:
#      Gender  Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0         1   27             6.1                 6                       42
# 1         1   28             6.2                 6                       60
# 2         1   28             6.2                 6                       60
# 3         1   28             5.9                 4                       30
# 4         1   28             5.9                 4                       30
# ..      ...  ...             ...               ...                      ...
# 369       0   59             8.1                 9                       75
# 370       0   59             8.0                 9                       75
# 371       0   59             8.1                 9                       75
# 372       0   59             8.1                 9                       75
# 373       0   59             8.1                 9                       75
#
# ...

# %%
data['Sleep Disorder'].value_counts()
# Out:
# Sleep Disorder
# 1    219
# 2     78
# 0     77
# Name: count, dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# Gender
# 1    189
# 0    185
# Name: count, dtype: int64

# %%
numeric_cols = data.select_dtypes(include='number')


correlation = numeric_cols.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
correlation = data.corr()

target_corr = correlation['Occupation_encoded'].sort_values(ascending=False)


print(target_corr)
# Out:
# Occupation_encoded         1.000000
# Gender                     0.116353
# Heart Rate                 0.002236
# Stress Level              -0.002678
# Quality of Sleep          -0.188216
# Sleep Duration            -0.232188
# Age                       -0.234549
# systolic                  -0.275095
# diastolic                 -0.328527
# Daily Steps               -0.329915
# Physical Activity Level   -0.369460
# Sleep Disorder            -0.541160
# Name: Occupation_encoded, dtype: float64

# %%
target_corr = target_corr.drop('Occupation_encoded')


plt.figure(figsize=(10, 6))
sns.barplot(x=target_corr.values, y=target_corr.index, palette='coolwarm')
plt.title('Correlation with Sleep Disorder')
plt.xlabel('Correlation Coefficient')
plt.ylabel('Features')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-50-01bf0012f2ca>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=target_corr.values, y=target_corr.index, palette='coolwarm')

# %%
 x = data.drop('Sleep Disorder',axis = 1)
 y = data['Sleep Disorder']

# %% [markdown]
# Randomforest

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# create mmodel = RandomForestClassif
model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
model = model.fit(x_train, y_train)

# %%
y_pred = model.predict(x_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.88
#
# Confusion Matrix:
#  [[13  1  2]
#  [ 1 42  0]
#  [ 4  1 11]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.81      0.76        16
#            1       0.95      0.98      0.97        43
#            2       0.85      0.69      0.76        16
#
#     accuracy                           0.88        75
#    macro avg       0.84      0.83      0.83        75
# weighted avg       0.88      0.88      0.88        75

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
             xticklabels=['Predicted 0', 'Predicted 1', 'Predicted 2'],
             yticklabels=['Actual 0', 'Actual 1', 'Actual 2'])
# Out:
# <Axes: >

# %% [markdown]
# في هذا المشروع تبين لدي عدد من العوامل التي لها دور كبير جدا في اضظراب النوم ومن خلال اجراء هذه الدراسة وجدت من اهم العوامل التي قد تؤثر على جودة النوم هي الوظائف حيث يكون لها التأثير الكبير على النوم ماهي الحلول التي من المفترض العمل عليها هي : حسب طبيعة العمل طبيعة عمل المهندس تختلف عن طبيعة عمل الطبيب والطبيب يختلف عن المحاسب وو الاعمال الشاقة والمتعبة والتي تتطلب الجهد والتركيز العالي من المفترض بأن تقليل عدد ساعات العمل وعمل ساعات تناوب بين اصحاب المهن الشاقة للحصول على راحة تامة والنوم الكافي للحفاظ على التركيز فجودة النوم تؤثر بشكل مباشر على الصحة والتركيز , ايضا يمكن ان نقوم بجمع البيانات اكثر ومشاهدة طبيعة النوم لمنطقة معينة محاطة بالمقاهي وقياس نسبة ومعدل وجودة النوم في المنطقة سيعطينا انطباع كبير ومباشر
